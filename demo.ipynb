# %%
import matplotlib.pyplot as plt
from generator import generate_captcha

# %%
captcha,marks = generate_captcha()
plt.imshow(captcha)
plt.show()

# %%
import cv2
import numpy as np

# %%
blur = 4
dst = cv2.blur(captcha,(blur,blur))
plt.imshow(dst)
plt.show()
